# %% [markdown]
# # VIZZLE - Virtual Try-On Model Evaluation (Colab GPU Harness)
# Run real GPU inference for CatVTON & IDM-VTON on Google Colab (T4 / A100 GPU).
# Measures real `time.perf_counter()` latency and calculates estimated GPU cost.

# %%
# 1. Check GPU
# !nvidia-smi

# %%
# 2. Clone or run setup
# !python colab_setup.py

# %%
# 3. Run full 10-category benchmark suite on GPU
# !python benchmark_runner.py

# %%
# 4. View results summary
with open('results/benchmark_summary.md', 'r') as f:
    print(f.read())
